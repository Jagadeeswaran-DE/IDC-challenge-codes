# %%
# %pip install kaggle

# %%
import os

# Replace with your Kaggle credentials from kaggle.json
os.environ['KAGGLE_USERNAME'] = "jagadeeswaranvpm"
os.environ['KAGGLE_KEY'] = "KGAT_********************"

# Verify setup
print("Kaggle credentials configured!")

# %%
# %sql
create catalog if not exists idc;

# %%
# %sql
create schema if not exists idc.idc_kaggle;

# %%
# %sql
create volume if not exists idc.idc_kaggle.ecom_data;

# %%
# %sh
cd /Volumes/idc/idc_kaggle/ecom_data
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %%
# %sh 
unzip -o ecommerce-behavior-data-from-multi-category-store.zip

# %%
# !ls -lh

# %%
# !rm -f ecommerce-behavior-data-from-multi-category-store.zip

# %%
# !ls -lh
