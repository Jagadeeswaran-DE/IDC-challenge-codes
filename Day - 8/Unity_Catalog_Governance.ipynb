# %%
# %sql
create catalog if not exists ecom_idc;

use catalog ecom_idc;

# %%
# %sql
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;

# %%
# %sql
select * from delta.`/Volumes/idc/idc_kaggle/ecom_data/ecom_oct/bronze`;

# %%
# %sql
create table if not exists ecom_idc.bronze.events select * from delta.`/Volumes/idc/idc_kaggle/ecom_data/ecom_oct/bronze`;
create table if not exists ecom_idc.silver.events select * from delta.`/Volumes/idc/idc_kaggle/ecom_data/ecom_oct/silver`;
create table if not exists ecom_idc.gold.prod select * from delta.`/Volumes/idc/idc_kaggle/ecom_data/ecom_oct/gold/product`;

# %%
# %sql
GRANT SELECT ON TABLE ecom_idc.gold.prod TO `21ai016@nandhaengg.org`;
GRANT ALL PRIVILEGES ON SCHEMA ecom_idc.bronze TO `21ai016@nandhaengg.org`;

# %%
# %sql
SHOW GRANTS ON TABLE ecom_idc.gold.prod;

# %%
# %sql 
SHOW GRANTS ON SCHEMA ecom_idc.bronze;

# %%
# %sql
CREATE VIEW ecom_idc.gold.products AS
SELECT product_id, revenue, conversion_rate
FROM ecom_idc.gold.prod
WHERE purchases > 10
ORDER BY revenue DESC LIMIT 100;

# %%
# %sql
select * from ecom_idc.gold.products;
